# %% [markdown]
# COSINE SIMILARITY AND HUNGARIAN ALGORITHM

# %%
import pandas as pd
from sklearn.metrics.pairwise import cosine_similarity
from scipy.optimize import linear_sum_assignment
import numpy as np
from sklearn.preprocessing import StandardScaler

data = pd.read_excel("Housing_Data.xlsx")

print(data.head())

# Check for missing values in the dataset
print("Missing values before cleaning:")
print(data.isnull().sum())

# List of columns to drop
columns_to_drop = [
    "ID", "Email", "Name", "Full Name (First, Middle, Last Names)",
    "Year Group", "Student ID Number", "Phone Number",
    "Are you interested in staying in Ashesi's halls of residence next academic year?",
    "What is the specific need?", "Please state any special accomodations you will need."
]

# Drops the specified columns
data_cleaned = data.drop(columns=columns_to_drop)

# Replaces NaN values with 0
data_cleaned = data_cleaned.fillna(0)

# Checks if there are any missing values after cleaning
print("\nMissing values after cleaning:")
print(data_cleaned.isnull().sum())

# Displays the cleaned dataset
print("\nCleaned Data Info:")
print(data_cleaned.head())
# Out:
#    ID                            Email                      Name  \
# 0   1      ababasa.roger@ashesi.edu.gh             Ababasa Roger
# 1   2  abdoul.kandegomni@ashesi.edu.gh  Abdoul Nasser Kandégomni
# 2   3    abdoulaye.garba@ashesi.edu.gh  Abdoulaye Moumouni Garba
# 3   4    rahman.abubakar@ashesi.edu.gh     Abdul Rahman Abubakar
# 4   5        abdul.salia@ashesi.edu.gh         Abdul-Mumin Salia
#
#   Are you interested in staying in Ashesi's halls of residence next academic year?  \
# 0                                                Yes
# 1                                                Yes
# 2                                                Yes
# 3                                                Yes
# 4                                                Yes
#
#   Full Name (First, Middle, Last Names) Gender     Year Group  \
# 0                         Roger Ababasa   Male  Class of 2027
# 1       Abdoul Nasser Djibo kandégomni    Male  Class of 2027
# 2             Abdoulaye Moumouni Garba    Male  Class of 2027
# 3                 Abdul Rahman Abubakar   Male  Class of 2025
# 4                     Abdul-Mumin Salia   Male  Class of 2025
#
#    Student ID Number     Phone Number Are you on any form of financial aid?  \
# 0           34362027        558305986                                   Yes
# 1           30712027        503510526                                   Yes
# 2           30162027  23350 380 0579                                    Yes
# 3           85922025        549034478                                   Yes
# 4           80072025        558075707                                   Yes
#
#      What's your financial aid status?  \
# 0  Mastercard Foundation Scholar (MCF)
# 1  Mastercard Foundation Scholar (MCF)
# 2  Mastercard Foundation Scholar (MCF)
# 3  Mastercard Foundation Scholar (MCF)
# 4  Mastercard Foundation Scholar (MCF)
#
#   Do you have any special accessibility needs? What is the specific need?  \
# 0                                           No                        NaN
# 1                                           No                        NaN
# 2                                           No                        NaN
# 3                                           No                        NaN
# 4                                           No                        NaN
#
#   Please state any special accomodations you will need.  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   How would you describe your personality?  \
# 0                     Somewhere in between
# 1                     Somewhere in between
# 2                         I am introverted
# 3                         I am introverted
# 4                         I am extroverted
#
#   What time do you typically go to bed on weeknights?  \
# 0                   Between 10PM and Midnight (12AM)
# 1                              After Midnight (12AM)
# 2                                    10PM or earlier
# 3                              After Midnight (12AM)
# 4                              After Midnight (12AM)
#
#   Where do you prefer to do homework/study? What do you enjoy doing for fun?  \
# 0                               In the room                Relaxing/Sleeping
# 1                               In the room                Relaxing/Sleeping
# 2                               In the room   Going for events on/off-campus
# 3                               In the room                Relaxing/Sleeping
# 4                               In the room                Relaxing/Sleeping
#
#   Do you enjoy having friends over in your room?  \
# 0                            Yup, but not always
# 1                            Yup, but not always
# 2                   Not really, but I don't mind
# 3                            Yup, but not always
# 4                            Yup, but not always
#
#   How would your friends describe you in one word?
# 0                                         Friendly
# 1                                         Friendly
# 2                                         Friendly
# 3                                      Responsible
# 4                                         Friendly
# Missing values before cleaning:
# ID                                                                                    0
# Email                                                                                 0
# Name                                                                                  0
# Are you interested in staying in Ashesi's halls of residence next academic year?      0
# Full Name (First, Middle, Last Names)                                                11
# Gender                                                                                0
# Year Group                                                                            0
# Student ID Number                                                                     0
# Phone Number                                                                         21
# Are you on any form of financial aid?                                                11
# What's your financial aid status?                                                    11
# Do you have any special accessibility needs?                                         21
# What is the specific need?                                                          507
# Please state any special accomodations you will need.                               507
# How would you describe your personality?                                             21
# What time do you typically go to bed on weeknights?                                  21
# Where do you prefer to do homework/study?                                            21
# What do you enjoy doing for fun?                                                     21
# Do you enjoy having friends over in your room?                                       21
# How would your friends describe you in one word?                                     22
# dtype: int64
#
# Missing values after cleaning:
# Gender                                                 0
# Are you on any form of financial aid?                  0
# What's your financial aid status?                      0
# Do you have any special accessibility needs?           0
# How would you describe your personality?               0
# What time do you typically go to bed on weeknights?    0
# Where do you prefer to do homework/study?              0
# What do you enjoy doing for fun?                       0
# Do you enjoy having friends over in your room?         0
# How would your friends describe you in one word?       0
# dtype: int64
#
# Cleaned Data Info:
#   Gender Are you on any form of financial aid?  \
# 0   Male                                   Yes
# 1   Male                                   Yes
# 2   Male                                   Yes
# 3   Male                                   Yes
# 4   Male                                   Yes
#
#      What's your financial aid status?  \
# 0  Mastercard Foundation Scholar (MCF)
# 1  Mastercard Foundation Scholar (MCF)
# 2  Mastercard Foundation Scholar (MCF)
# 3  Mastercard Foundation Scholar (MCF)
# 4  Mastercard Foundation Scholar (MCF)
#
#   Do you have any special accessibility needs?  \
# 0                                           No
# 1                                           No
# 2                                           No
# 3                                           No
# 4                                           No
#
#   How would you describe your personality?  \
# 0                     Somewhere in between
# 1                     Somewhere in between
# 2                         I am introverted
# 3                         I am introverted
# 4                         I am extroverted
#
#   What time do you typically go to bed on weeknights?  \
# 0                   Between 10PM and Midnight (12AM)
# 1                              After Midnight (12AM)
# 2                                    10PM or earlier
# 3                              After Midnight (12AM)
# 4                              After Midnight (12AM)
#
#   Where do you prefer to do homework/study? What do you enjoy doing for fun?  \
# 0                               In the room                Relaxing/Sleeping
# 1                               In the room                Relaxing/Sleeping
# 2                               In the room   Going for events on/off-campus
# 3                               In the room                Relaxing/Sleeping
# 4                               In the room                Relaxing/Sleeping
#
#   Do you enjoy having friends over in your room?  \
# 0                            Yup, but not always
# 1                            Yup, but not always
# 2                   Not really, but I don't mind
# 3                            Yup, but not always
# 4                            Yup, but not always
#
#   How would your friends describe you in one word?
# 0                                         Friendly
# 1                                         Friendly
# 2                                         Friendly
# 3                                      Responsible
# 4                                         Friendly

# %%
# Mapping for each column
gender_mapping = {'Male': 0, 'Female': 1}
financial_aid_mapping = {'Yes': 1, 'No': 0}
personality_mapping = {'I am introverted': 0, 'Somewhere in between': 1, 'I am extroverted': 2}
bedtime_mapping = {'10PM or earlier': 0, 'Between 10PM and Midnight (12AM)': 1, 'After Midnight (12AM)': 2}
study_location_mapping = {'In the room': 0, 'Away from the room': 1}
fun_activity_mapping = {'Relaxing/Sleeping': 0, 'Hanging out with friends': 1, 'Going for events on/off-campus': 2}
friends_over_mapping = {'Nope!': 0, 'Not really, but I don\'t mind': 1, 'Yup, all the time': 2, 'Yup, but not always': 3}
friends_description_mapping = {'Friendly': 0, 'Fun': 1, 'Responsible': 2, 'Chill': 3, 'Organized': 4}

# Applies the transformations
data_cleaned['Gender'] = data_cleaned['Gender'].replace(gender_mapping)
data_cleaned['Are you on any form of financial aid?'] = data_cleaned['Are you on any form of financial aid?'].replace(financial_aid_mapping)
data_cleaned['How would you describe your personality?'] = data_cleaned['How would you describe your personality?'].replace(personality_mapping)
data_cleaned['What time do you typically go to bed on weeknights?'] = data_cleaned['What time do you typically go to bed on weeknights?'].replace(bedtime_mapping)
data_cleaned['Where do you prefer to do homework/study?'] = data_cleaned['Where do you prefer to do homework/study?'].replace(study_location_mapping)
data_cleaned['What do you enjoy doing for fun?'] = data_cleaned['What do you enjoy doing for fun?'].replace(fun_activity_mapping)
data_cleaned['Do you enjoy having friends over in your room?'] = data_cleaned['Do you enjoy having friends over in your room?'].replace(friends_over_mapping)
data_cleaned['How would your friends describe you in one word?'] = data_cleaned['How would your friends describe you in one word?'].replace(friends_description_mapping)

# Handling any other unlisted options
data_cleaned['How would your friends describe you in one word?'] = data_cleaned['How would your friends describe you in one word?'].apply(
    lambda x: friends_description_mapping.get(x, 5)
)

# Displays the transformed data
print(data_cleaned.head())
# Out:
#    Gender  Are you on any form of financial aid?  \
# 0       0                                      1
# 1       0                                      1
# 2       0                                      1
# 3       0                                      1
# 4       0                                      1
#
#      What's your financial aid status?  \
# 0  Mastercard Foundation Scholar (MCF)
# 1  Mastercard Foundation Scholar (MCF)
# 2  Mastercard Foundation Scholar (MCF)
# 3  Mastercard Foundation Scholar (MCF)
# 4  Mastercard Foundation Scholar (MCF)
#
#   Do you have any special accessibility needs?  \
# 0                                           No
# 1                                           No
# 2                                           No
# 3                                           No
# 4                                           No
#
#    How would you describe your personality?  \
# 0                                         1
# 1                                         1
# 2                                         0
# 3                                         0
# 4                                         2
#
#    What time do you typically go to bed on weeknights?  \
# 0                                                  1
# 1                                                  2
# 2                                                  0
# 3                                                  2
# 4                                                  2
#
#    Where do you prefer to do homework/study?  \
# 0                                          0
# 1                                          0
# 2                                          0
# 3                                          0
# 4                                          0
#
#    What do you enjoy doing for fun?  \
# 0                                 0
# 1                                 0
# 2                                 2
# 3                                 0
# 4                                 0
#
#    Do you enjoy having friends over in your room?  \
# 0                                               3
# 1                                               3
# 2                                               1
# 3                                               3
# 4                                               3
#
#    How would your friends describe you in one word?
# 0                                                 5
# 1                                                 5
# 2                                                 5
# 3                                                 5
# 4                                                 5
# <ipython-input-89-9b045c41ec27>:12: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data_cleaned['Gender'] = data_cleaned['Gender'].replace(gender_mapping)
# <ipython-input-89-9b045c41ec27>:13: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data_cleaned['Are you on any form of financial aid?'] = data_cleaned['Are you on any form of financial aid?'].replace(financial_aid_mapping)
# <ipython-input-89-9b045c41ec27>:14: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data_cleaned['How would you describe your personality?'] = data_cleaned['How would you describe your personality?'].replace(personality_mapping)
# <ipython-input-89-9b045c41ec27>:15: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data_cleaned['What time do you typically go to bed on weeknights?'] = data_cleaned['What time do you typically go to bed on weeknights?'].replace(bedtime_mapping)
# <ipython-input-89-9b045c41ec27>:16: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data_cleaned['Where do you prefer to do homework/study?'] = data_cleaned['Where do you prefer to do homework/study?'].replace(study_location_mapping)
# <ipython-input-89-9b045c41ec27>:17: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data_cleaned['What do you enjoy doing for fun?'] = data_cleaned['What do you enjoy doing for fun?'].replace(fun_activity_mapping)
# <ipython-input-89-9b045c41ec27>:18: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data_cleaned['Do you enjoy having friends over in your room?'] = data_cleaned['Do you enjoy having friends over in your room?'].replace(friends_over_mapping)

# %%
# Separates the data into males and females
males = data_cleaned[data_cleaned['Gender'] == 0]
females = data_cleaned[data_cleaned['Gender'] == 1]

# Displays the size of each
print("Number of males:", len(males))
print("Number of females:", len(females))

# Displays the first few rows of each
print("\nMales Group:")
print(males.head())

print("\nFemales Group:")
print(females.head())
# Out:
# Number of males: 222
# Number of females: 305
#
# Males Group:
#    Gender  Are you on any form of financial aid?  \
# 0       0                                      1
# 1       0                                      1
# 2       0                                      1
# 3       0                                      1
# 4       0                                      1
#
#      What's your financial aid status?  \
# 0  Mastercard Foundation Scholar (MCF)
# 1  Mastercard Foundation Scholar (MCF)
# 2  Mastercard Foundation Scholar (MCF)
# 3  Mastercard Foundation Scholar (MCF)
# 4  Mastercard Foundation Scholar (MCF)
#
#   Do you have any special accessibility needs?  \
# 0                                           No
# 1                                           No
# 2                                           No
# 3                                           No
# 4                                           No
#
#    How would you describe your personality?  \
# 0                                         1
# 1                                         1
# 2                                         0
# 3                                         0
# 4                                         2
#
#    What time do you typically go to bed on weeknights?  \
# 0                                                  1
# 1                                                  2
# 2                                                  0
# 3                                                  2
# 4                                                  2
#
#    Where do you prefer to do homework/study?  \
# 0                                          0
# 1                                          0
# 2                                          0
# 3                                          0
# 4                                          0
#
#    What do you enjoy doing for fun?  \
# 0                                 0
# 1                                 0
# 2                                 2
# 3                                 0
# 4                                 0
#
#    Do you enjoy having friends over in your room?  \
# 0                                               3
# 1                                               3
# 2                                               1
# 3                                               3
# 4                                               3
#
#    How would your friends describe you in one word?
# 0                                                 5
# 1                                                 5
# 2                                                 5
# 3                                                 5
# 4                                                 5
#
# Females Group:
#     Gender  Are you on any form of financial aid?  \
# 6        1                                      1
# 9        1                                      1
# 10       1                                      1
# 13       1                                      0
# 14       1                                      0
#
#       What's your financial aid status?  \
# 6   Mastercard Foundation Scholar (MCF)
# 9            Ashesi Financial Aid (AFA)
# 10  Mastercard Foundation Scholar (MCF)
# 13                Full Fee Paying (FFP)
# 14                Full Fee Paying (FFP)
#
#    Do you have any special accessibility needs?  \
# 6                                            No
# 9                                            No
# 10                                           No
# 13                                           No
# 14                                           No
#
#     How would you describe your personality?  \
# 6                                          1
# 9                                          1
# 10                                         1
# 13                                         0
# 14                                         1
#
#     What time do you typically go to bed on weeknights?  \
# 6                                                   2
# 9                                                   1
# 10                                                  2
# 13                                                  1
# 14                                                  1
#
#     Where do you prefer to do homework/study?  \
# 6                                           0
# 9                                           0
# 10                                          0
# 13                                          0
# 14                                          1
#
#     What do you enjoy doing for fun?  \
# 6                                  2
# 9                                  0
# 10                                 0
# 13                                 1
# 14                                 0
#
#     Do you enjoy having friends over in your room?  \
# 6                                                1
# 9                                                3
# 10                                               3
# 13                                               2
# 14                                               3
#
#     How would your friends describe you in one word?
# 6                                                  5
# 9                                                  5
# 10                                                 5
# 13                                                 5
# 14                                                 5

# %%
males_features = males[['Are you on any form of financial aid?', 'How would you describe your personality?',
                         'What time do you typically go to bed on weeknights?', 'Where do you prefer to do homework/study?',
                         'What do you enjoy doing for fun?', 'Do you enjoy having friends over in your room?',
                         'How would your friends describe you in one word?']]

# Normalizes the data to prevent high similarity
scaler = StandardScaler()
males_features_normalized = scaler.fit_transform(males_features)

# Calculates the cosine similarity matrix for males
similarity_matrix_males = cosine_similarity(males_features_normalized)

# Ensures no student is paired with themselves
np.fill_diagonal(similarity_matrix_males, 0)

groups = []

students = list(range(len(males)))

# Loops until all students are grouped
while students:
    group_size = np.random.randint(2, 5)

    # Makes sure the remaining students are enough for the group
    group_size = min(group_size, len(students))

    # Create a group from the most similar students
    group = []
    for _ in range(group_size):
        if not students:
            break

        # Gets the student with the highest similarity to any in the current group
        if not group:
            student = students.pop(np.random.randint(len(students)))
        else:
            # Calculates similarity to already chosen students and selects the highest
            similarities = np.sum(similarity_matrix_males[students][:, group], axis=1)
            student = students.pop(np.argmax(similarities))

        group.append(student)

    groups.append(group)

# Display the grouping results
print("\nMale Roommate Groups:")
for idx, group in enumerate(groups, start=1):
    room_name = f"Room M{idx}"
    students_in_room = [f"Student {males.index[student_id]}" for student_id in group]
    print(f"{room_name}: {' and '.join(students_in_room)}")
# Out:
# Male Roommate Groups:
# Room M1: Student 451 and Student 55
# Room M2: Student 318 and Student 1
# Room M3: Student 146 and Student 287 and Student 388
# Room M4: Student 373 and Student 0 and Student 103 and Student 106
# Room M5: Student 74 and Student 126 and Student 145 and Student 154
# Room M6: Student 241 and Student 234 and Student 235 and Student 262
# Room M7: Student 239 and Student 162 and Student 174 and Student 185
# Room M8: Student 504 and Student 85 and Student 363
# Room M9: Student 438 and Student 271
# Room M10: Student 333 and Student 66 and Student 227
# Room M11: Student 5 and Student 508
# Room M12: Student 144 and Student 110 and Student 237
# Room M13: Student 132 and Student 114 and Student 184 and Student 383
# Room M14: Student 82 and Student 112 and Student 130 and Student 242
# Room M15: Student 490 and Student 190
# Room M16: Student 403 and Student 143 and Student 220 and Student 382
# Room M17: Student 351 and Student 113 and Student 344
# Room M18: Student 270 and Student 142
# Room M19: Student 89 and Student 61 and Student 487
# Room M20: Student 341 and Student 434
# Room M21: Student 280 and Student 279 and Student 386 and Student 471
# Room M22: Student 513 and Student 125
# Room M23: Student 327 and Student 465 and Student 511 and Student 512
# Room M24: Student 424 and Student 265 and Student 479 and Student 491
# Room M25: Student 524 and Student 516 and Student 519
# Room M26: Student 276 and Student 83 and Student 49 and Student 168
# Room M27: Student 463 and Student 111
# Room M28: Student 323 and Student 195 and Student 86 and Student 94
# Room M29: Student 476 and Student 244 and Student 73 and Student 402
# Room M30: Student 148 and Student 29
# Room M31: Student 109 and Student 120 and Student 30
# Room M32: Student 115 and Student 84 and Student 203 and Student 222
# Room M33: Student 478 and Student 240 and Student 260
# Room M34: Student 8 and Student 458
# Room M35: Student 520 and Student 521 and Student 379
# Room M36: Student 500 and Student 316 and Student 330 and Student 462
# Room M37: Student 211 and Student 76 and Student 56 and Student 189
# Room M38: Student 2 and Student 209 and Student 102 and Student 470
# Room M39: Student 343 and Student 141
# Room M40: Student 395 and Student 261 and Student 79
# Room M41: Student 349 and Student 133 and Student 151 and Student 208
# Room M42: Student 459 and Student 460 and Student 196 and Student 290
# Room M43: Student 387 and Student 259
# Room M44: Student 445 and Student 153
# Room M45: Student 285 and Student 380 and Student 139 and Student 489
# Room M46: Student 100 and Student 267 and Student 93
# Room M47: Student 11 and Student 377 and Student 435 and Student 27
# Room M48: Student 475 and Student 210 and Student 391 and Student 147
# Room M49: Student 454 and Student 436
# Room M50: Student 456 and Student 3 and Student 152
# Room M51: Student 450 and Student 437 and Student 4 and Student 7
# Room M52: Student 266 and Student 505
# Room M53: Student 401 and Student 334
# Room M54: Student 348 and Student 250 and Student 305
# Room M55: Student 291 and Student 272
# Room M56: Student 278 and Student 233 and Student 243 and Student 77
# Room M57: Student 466 and Student 455 and Student 467 and Student 427
# Room M58: Student 446 and Student 498
# Room M59: Student 384 and Student 368
# Room M60: Student 346 and Student 149 and Student 171 and Student 25
# Room M61: Student 156 and Student 200 and Student 447
# Room M62: Student 286 and Student 186 and Student 439 and Student 134
# Room M63: Student 493 and Student 251 and Student 477 and Student 108
# Room M64: Student 495 and Student 191 and Student 256
# Room M65: Student 370 and Student 396 and Student 24
# Room M66: Student 312 and Student 283
# Room M67: Student 26 and Student 155 and Student 449
# Room M68: Student 232 and Student 35 and Student 326
# Room M69: Student 247 and Student 193 and Student 399
# Room M70: Student 284 and Student 50 and Student 12 and Student 150
# Room M71: Student 51 and Student 68 and Student 442
# Room M72: Student 332

# %%
females_features = females[['Are you on any form of financial aid?', 'How would you describe your personality?',
                             'What time do you typically go to bed on weeknights?', 'Where do you prefer to do homework/study?',
                             'What do you enjoy doing for fun?', 'Do you enjoy having friends over in your room?',
                             'How would your friends describe you in one word?']]

# Normalizes the data to prevent high similarity due to feature scale
scaler = StandardScaler()
females_features_normalized = scaler.fit_transform(females_features)

# Calculates the cosine similarity matrix for females
similarity_matrix_females = cosine_similarity(females_features_normalized)

# Ensures no student is paired with themselves
np.fill_diagonal(similarity_matrix_females, 0)

groups_females = []

students_females = list(range(len(females)))

while students_females:
    group_size = np.random.randint(2, 5)

    group_size = min(group_size, len(students_females))

    # Creates a group from the most similar students
    group = []
    for _ in range(group_size):
        if not students_females:
            break

        if not group:
            student = students_females.pop(np.random.randint(len(students_females)))
        else:
            # Calculates similarity to already chosen students and select the highest
            similarities = np.sum(similarity_matrix_females[students_females][:, group], axis=1)
            student = students_females.pop(np.argmax(similarities))

        group.append(student)

    groups_females.append(group)

# Display the grouping results
print("\nFemale Roommate Groups:")
for idx, group in enumerate(groups_females, start=1):
    room_name = f"Room F{idx}"
    students_in_room = [f"Student {females.index[student_id]}" for student_id in group]
    print(f"{room_name}: {' and '.join(students_in_room)}")
# Out:
# Female Roommate Groups:
# Room F1: Student 317 and Student 9
# Room F2: Student 218 and Student 104 and Student 118
# Room F3: Student 40 and Student 180 and Student 503 and Student 221
# Room F4: Student 406 and Student 39 and Student 172
# Room F5: Student 347 and Student 128 and Student 159 and Student 179
# Room F6: Student 350 and Student 60
# Room F7: Student 88 and Student 116 and Student 119
# Room F8: Student 188 and Student 62 and Student 224
# Room F9: Student 105 and Student 268 and Student 295
# Room F10: Student 360 and Student 421 and Student 63
# Room F11: Student 294 and Student 32 and Student 95
# Room F12: Student 187 and Student 408 and Student 69 and Student 392
# Room F13: Student 440 and Student 248 and Student 419 and Student 431
# Room F14: Student 522 and Student 517 and Student 518
# Room F15: Student 181 and Student 213 and Student 258
# Room F16: Student 31 and Student 18 and Student 96
# Room F17: Student 45 and Student 412
# Room F18: Student 6 and Student 19
# Room F19: Student 264 and Student 34 and Student 43 and Student 48
# Room F20: Student 215 and Student 53
# Room F21: Student 136 and Student 17 and Student 59 and Student 65
# Room F22: Student 16 and Student 97 and Student 410
# Room F23: Student 107 and Student 46 and Student 98 and Student 140
# Room F24: Student 469 and Student 123 and Student 319 and Student 340
# Room F25: Student 394 and Student 362 and Student 167
# Room F26: Student 122 and Student 164
# Room F27: Student 246 and Student 37 and Student 99 and Student 135
# Room F28: Student 176 and Student 198
# Room F29: Student 245 and Student 206 and Student 484 and Student 64
# Room F30: Student 367 and Student 356
# Room F31: Student 252 and Student 494 and Student 163 and Student 201
# Room F32: Student 57 and Student 138 and Student 409 and Student 502
# Room F33: Student 229 and Student 216 and Student 231 and Student 357
# Room F34: Student 300 and Student 177 and Student 219 and Student 353
# Room F35: Student 407 and Student 52
# Room F36: Student 354 and Student 47
# Room F37: Student 325 and Student 36 and Student 42
# Room F38: Student 10 and Student 41
# Room F39: Student 92 and Student 58 and Student 78 and Student 87
# Room F40: Student 468 and Student 254 and Student 400 and Student 28
# Room F41: Student 404 and Student 54 and Student 281
# Room F42: Student 71 and Student 72
# Room F43: Student 523 and Student 525
# Room F44: Student 253 and Student 117 and Student 415 and Student 298
# Room F45: Student 309 and Student 121 and Student 124 and Student 127
# Room F46: Student 182 and Student 91 and Student 443
# Room F47: Student 263 and Student 381
# Room F48: Student 197 and Student 21 and Student 166
# Room F49: Student 461 and Student 192 and Student 212
# Room F50: Student 398 and Student 416
# Room F51: Student 228 and Student 158 and Student 366
# Room F52: Student 428 and Student 131 and Student 432 and Student 481
# Room F53: Student 320 and Student 226 and Student 282 and Student 337
# Room F54: Student 355 and Student 204 and Student 299
# Room F55: Student 488 and Student 345 and Student 393
# Room F56: Student 301 and Student 293
# Room F57: Student 157 and Student 274
# Room F58: Student 464 and Student 315
# Room F59: Student 311 and Student 81 and Student 165
# Room F60: Student 497 and Student 129 and Student 361
# Room F61: Student 417 and Student 444 and Student 289 and Student 359
# Room F62: Student 80 and Student 214 and Student 217
# Room F63: Student 389 and Student 223 and Student 306
# Room F64: Student 238 and Student 173 and Student 175 and Student 199
# Room F65: Student 249 and Student 202 and Student 277 and Student 288
# Room F66: Student 352 and Student 23 and Student 14 and Student 411
# Room F67: Student 492 and Student 160 and Student 307
# Room F68: Student 335 and Student 329 and Student 473
# Room F69: Student 364 and Student 137 and Student 207
# Room F70: Student 372 and Student 506 and Student 507
# Room F71: Student 292 and Student 501 and Student 161
# Room F72: Student 236 and Student 303 and Student 378 and Student 453
# Room F73: Student 486 and Student 269 and Student 308
# Room F74: Student 430 and Student 310 and Student 22
# Room F75: Student 313 and Student 194
# Room F76: Student 33 and Student 20 and Student 75
# Room F77: Student 420 and Student 101 and Student 257
# Room F78: Student 70 and Student 365 and Student 297 and Student 302
# Room F79: Student 418 and Student 170
# Room F80: Student 375 and Student 314 and Student 358 and Student 413
# Room F81: Student 336 and Student 183 and Student 304 and Student 423
# Room F82: Student 514 and Student 509
# Room F83: Student 390 and Student 328
# Room F84: Student 422 and Student 67
# Room F85: Student 255 and Student 225
# Room F86: Student 457 and Student 499
# Room F87: Student 433 and Student 324
# Room F88: Student 44 and Student 322
# Room F89: Student 321 and Student 371 and Student 90 and Student 275
# Room F90: Student 480 and Student 425 and Student 426
# Room F91: Student 452 and Student 397 and Student 414
# Room F92: Student 230 and Student 205
# Room F93: Student 273 and Student 510 and Student 515 and Student 526
# Room F94: Student 496 and Student 448
# Room F95: Student 296 and Student 338 and Student 385 and Student 429
# Room F96: Student 485 and Student 376 and Student 405
# Room F97: Student 339 and Student 472 and Student 482 and Student 483
# Room F98: Student 441 and Student 374
# Room F99: Student 38 and Student 178 and Student 169 and Student 474
# Room F100: Student 13 and Student 15
# Room F101: Student 331 and Student 342 and Student 369
